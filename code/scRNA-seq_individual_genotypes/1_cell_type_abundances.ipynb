# %% [markdown]
# # Setup

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import scanpy as sc
import matplotlib.pyplot as plt
import pandas as pd
import anndata as ad
import scrnatools as rna
import seaborn as sns
import numpy as np
from scipy.stats import ttest_ind

# %%
# Setup figure params
plt.rcParams["pdf.use14corefonts"] = True
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = "Arial"
sc.set_figure_params(dpi=80, dpi_save=300, facecolor="white", frameon=False)
sns.set_context("paper")
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.grid"] = False

# %%
warnings.resetwarnings()

# %% [markdown]
# ## Set up file paths

# %% [markdown]
# ### demeter

# %%
rawDataPath = "/mnt/iacchus/joe/raw_data/"
processedDataPath = "/mnt/iacchus/joe/processed_data/"

# %% [markdown]
# ## Import data

# %%
aire = sc.read(f"{processedDataPath}/Fezf2_thymus_paper/h5ad_files/pairwise_processing/aire_TECs.h5ad")
fezf2 = sc.read(f"{processedDataPath}/Fezf2_thymus_paper/h5ad_files/pairwise_processing/fezf2_TECs.h5ad")

# %% [markdown]
# # Differential Density

# %% [markdown]
# ## Fezf2 KO

# %%
fezf2 = rna.tl.log_density_ratio(
    fezf2,
    group_by="genotype",
    groups=["WT", "Fezf2_KO"],
    key_added="Fezf2_KO/WT_genotype_density",
    latent_rep="X_umap",
)

# %%
sc.settings.figdir = "../../analysis/individual_genotypes/"
sc.pl.umap(
    fezf2,
    color="Fezf2_KO/WT_genotype_density",
    cmap="coolwarm",
    vmin=-0.75,
    vmax=0.75,
    save="_Fezf2_KO_density.pdf"
)
# Out:
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1H_Fezf2_KO_density.pdf

# %% [markdown]
# ## Aire KO

# %%
aire = rna.tl.log_density_ratio(
    aire,
    group_by="genotype",
    groups=["WT", "Aire_KO"],
    key_added="Aire_KO/WT_genotype_density",
    latent_rep="X_umap",
)

# %%
sc.settings.figdir = "../../analysis/individual_genotypes/"
sc.pl.umap(
    aire,
    color="Aire_KO/WT_genotype_density",
    cmap="coolwarm",
    vmin=-1.5,
    vmax=1.5,
    save="_Aire_KO_density.pdf"
)
# Out:
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1H_Aire_KO_density.pdf
