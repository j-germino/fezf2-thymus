# %% [markdown]
# # Setup

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import scanpy as sc
import seaborn as sns
import scrnatools as rna
import matplotlib.pyplot as plt

# %%
# Setup figure params
plt.rcParams["pdf.use14corefonts"] = True
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = "Arial"
sc.set_figure_params(dpi=80, dpi_save=300, facecolor="white", frameon=False)
sns.set_context("paper")
plt.rcParams["axes.grid"] = False
cmap = sns.color_palette("colorblind")

# %%
warnings.resetwarnings()

# %% [markdown]
# # Data paths

# %%
rawDataPath = "/mnt/iacchus/joe/raw_data/"
processedDataPath = "/mnt/iacchus/joe/processed_data/"

# %% [markdown]
# # Import data

# %%
aire = sc.read(f"{processedDataPath}/Fezf2_thymus_paper/h5ad_files/pairwise_processing/aire_TECs.h5ad")
fezf2 = sc.read(f"{processedDataPath}/Fezf2_thymus_paper/h5ad_files/pairwise_processing/fezf2_TECs.h5ad")

# %% [markdown]
# # Genotype/cell type plots

# %%
sc.settings.figdir = "../../analysis/individual_genotypes"
sc.pl.umap(
    aire,
    color=["majority_voting"],
    save="_S1G_Aire_cell_types.pdf"
)
sc.pl.umap(
    fezf2,
    color=["majority_voting"],
    save="_Fezf2_cell_types.pdf"
)
# Out:
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1G_Aire_cell_types.pdf
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1G_Fezf2_cell_types.pdf

# %%
sc.settings.figdir = "../../analysis/individual_genotypes"
sc.pl.umap(
    aire,
    color=["genotype"],
    groups=["Aire_KO"],
    save="_Aire_KO.pdf",
    palette=[cmap[1]]
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1G_Aire_KO.pdf

# %%
sc.settings.figdir = "../../analysis/individual_genotypes"
sc.pl.umap(
    fezf2,
    color=["genotype"],
    groups=["Fezf2_KO"],
    save="_Fezf2_KO.pdf",
    palette=[cmap[4]]
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1G_Fezf2_KO.pdf

# %%
sc.settings.figdir = "../../analysis/individual_genotypes"
sc.pl.umap(
    aire,
    color=["genotype"],
    groups=["WT"],
    save="_S1G_Aire_WT.pdf",
    palette=[cmap[0]]
)
sc.pl.umap(
    fezf2,
    color=["genotype"],
    groups=["WT"],
    save="_Fezf2_WT.pdf",
    palette=[cmap[0]]
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1G_Aire_WT.pdf
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S1/umap_S1G_Fezf2_WT.pdf
